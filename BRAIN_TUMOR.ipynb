# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D, Conv3D, BatchNormalization, Activation
from keras import backend as K
import os
from PIL import Image
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
import pandas as pd

# %%
path="Training"

# %%
classes = os.listdir(path)

# %%
enc = OneHotEncoder()
enc.fit([[0], [1], [2], [3]]) 
def names(number):
    if(number == 0):
        return classes[0]
    elif(number == 1):
        return classes[1]
    elif(number == 2):
        return classes[2]
    elif(number == 3):
        return classes[3]

# %%
trainData = []
trainLabel = []
dim = (150, 150)
trainPath ="Training"
index = 0
for dir in os.listdir(trainPath):
    filePaths = []
    subDir = os.path.join(trainPath, dir)
    for file in os.listdir(subDir):
        imgFullPath = os.path.join(subDir, file)
        filePaths.append(imgFullPath)
        img = Image.open(imgFullPath)
        x = img.resize(dim)
        x = np.array(x)
        trainData.append(np.array(x))
        trainLabel.append(enc.transform([[index]]).toarray())
    print(names(index))
    print(str(dir))
    index += 1
    
trainData = np.array(trainData)
trainLabel = np.array(trainLabel).reshape(3815, 4)
print(trainData.shape)
print(trainLabel.shape)
# Out:
# glioma_tumor
# glioma_tumor
# meningioma_tumor
# meningioma_tumor
# no_tumor
# no_tumor
# pituitary_tumor
# pituitary_tumor
# (3815, 150, 150, 3)
# (3815, 4)

# %%
testData = []
testLabel = []
dim = (150, 150)
testPath = "Testing"
index = 0
for dir in os.listdir(testPath):
    filePaths = []
    subDir = os.path.join(testPath, dir)
    for file in os.listdir(subDir):
        imgFullPath = os.path.join(subDir, file)
        filePaths.append(imgFullPath)
        img = Image.open(imgFullPath)
        x = img.resize(dim)
        x = np.array(x)
        testData.append(np.array(x))
        testLabel.append(enc.transform([[index]]).toarray())
    print(names(index))
    print(str(dir))
    index += 1
testData = np.array(testData)
testLabel = np.array(testLabel).reshape(394, 4)
print(testData.shape)
print(testLabel.shape)
# Out:
# glioma_tumor
# glioma_tumor
# meningioma_tumor
# meningioma_tumor
# no_tumor
# no_tumor
# pituitary_tumor
# pituitary_tumor
# (394, 150, 150, 3)
# (394, 4)

# %%
model = Sequential()

model.add(Conv2D(32, (3, 3), input_shape=(150,150,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(32, (3, 3))) 
model.add(Activation('relu'))           
model.add(MaxPooling2D(pool_size=(2, 2)))  
model.add(Flatten())
model.add(Dense(32))
model.add(Activation('relu'))
model.add(Dropout(0.25))
model.add(Dense(4))
model.add(Activation('softmax'))

model.compile(loss = "categorical_crossentropy", optimizer='adam',metrics=["accuracy"])
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 32)      896
#
#  activation (Activation)     (None, 148, 148, 32)      0
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 32)        9248
#
#  activation_1 (Activation)   (None, 72, 72, 32)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 41472)             0
#
#  dense (Dense)               (None, 32)                1327136
#
#  activation_2 (Activation)   (None, 32)                0
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_1 (Dense)             (None, 4)                 132
#
#  activation_3 (Activation)   (None, 4)                 0
#
# =================================================================
# Total params: 1,337,412
# Trainable params: 1,337,412
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
history = model.fit(trainData, trainLabel,batch_size = 32, epochs = 20, verbose=1,validation_data=(testData, testLabel))
# Out:
# Epoch 1/20
# 120/120 [==============================] - 37s 303ms/step - loss: 3.8037 - accuracy: 0.6013 - val_loss: 1.4870 - val_accuracy: 0.4061
# Epoch 2/20
# 120/120 [==============================] - 33s 279ms/step - loss: 0.5061 - accuracy: 0.8068 - val_loss: 3.4100 - val_accuracy: 0.4315
# Epoch 3/20
# 120/120 [==============================] - 31s 259ms/step - loss: 0.3995 - accuracy: 0.8448 - val_loss: 3.1457 - val_accuracy: 0.5660
# Epoch 4/20
# 120/120 [==============================] - 31s 256ms/step - loss: 0.2822 - accuracy: 0.8875 - val_loss: 3.6761 - val_accuracy: 0.6218
# Epoch 5/20
# 120/120 [==============================] - 31s 255ms/step - loss: 0.2486 - accuracy: 0.8988 - val_loss: 4.3705 - val_accuracy: 0.6497
# Epoch 6/20
# 120/120 [==============================] - 2921s 25s/step - loss: 0.2165 - accuracy: 0.9140 - val_loss: 6.5558 - val_accuracy: 0.7005
# Epoch 7/20
# 120/120 [==============================] - 32s 263ms/step - loss: 0.1826 - accuracy: 0.9258 - val_loss: 4.3367 - val_accuracy: 0.7107
# Epoch 8/20
# 120/120 [==============================] - 32s 270ms/step - loss: 0.1839 - accuracy: 0.9263 - val_loss: 5.9148 - val_accuracy: 0.6574
# Epoch 9/20
# 120/120 [==============================] - 32s 265ms/step - loss: 0.1855 - accuracy: 0.9345 - val_loss: 7.5102 - val_accuracy: 0.6904
# Epoch 10/20
# 120/120 [==============================] - 33s 272ms/step - loss: 0.1733 - accuracy: 0.9326 - val_loss: 7.3328 - val_accuracy: 0.6751
# Epoch 11/20
# 120/120 [==============================] - 29s 242ms/step - loss: 0.1315 - accuracy: 0.9463 - val_loss: 7.5881 - val_accuracy: 0.6929
# Epoch 12/20
# 120/120 [==============================] - 31s 259ms/step - loss: 0.1142 - accuracy: 0.9484 - val_loss: 5.6816 - val_accuracy: 0.7056
# Epoch 13/20
# 120/120 [==============================] - 31s 257ms/step - loss: 0.1180 - accuracy: 0.9567 - val_loss: 6.5921 - val_accuracy: 0.7030
# Epoch 14/20
# 120/120 [==============================] - 30s 248ms/step - loss: 0.0834 - accuracy: 0.9664 - val_loss: 7.2023 - val_accuracy: 0.7360
# Epoch 15/20
# 120/120 [==============================] - 29s 246ms/step - loss: 0.1311 - accuracy: 0.9523 - val_loss: 8.1247 - val_accuracy: 0.7030
# Epoch 16/20
# 120/120 [==============================] - 32s 263ms/step - loss: 0.1103 - accuracy: 0.9583 - val_loss: 7.2864 - val_accuracy: 0.7107
# Epoch 17/20
# 120/120 [==============================] - 29s 238ms/step - loss: 0.1008 - accuracy: 0.9573 - val_loss: 6.9754 - val_accuracy: 0.7208
# Epoch 18/20
# 120/120 [==============================] - 32s 265ms/step - loss: 0.0793 - accuracy: 0.9688 - val_loss: 5.9165 - val_accuracy: 0.7259
# Epoch 19/20
# 120/120 [==============================] - 31s 256ms/step - loss: 0.0705 - accuracy: 0.9709 - val_loss: 7.0073 - val_accuracy: 0.7157
# Epoch 20/20
# 120/120 [==============================] - 29s 241ms/step - loss: 0.0868 - accuracy: 0.9675 - val_loss: 5.4581 - val_accuracy: 0.7259

# %%
model.save("brain-tumor-model.h5")

# %%
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Test', 'Validation'], loc='upper right')
plt.show()

# %%
# Plot training & validation loss values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Test', 'Validation'], loc='upper right')
plt.show()

# %%
img = Image.open('testing/no_tumor/image(104).jpg')
x = np.array(img.resize(dim))
x = x.reshape(1,150,150,3)
answ = model.predict_on_batch(x)
classification = np.where(answ == np.amax(answ))[1][0]
imshow(img)
print(str(answ[0][classification]*100) + '% Confidence This Is ' + names(classification))
# Out:
# 98.48325848579407% Confidence This Is no_tumor

# %%
img = Image.open('testing/meningioma_tumor/image(27).jpg')
x = np.array(img.resize(dim))
x = x.reshape(1,150,150,3)
answ = model.predict_on_batch(x)
classification = np.where(answ == np.amax(answ))[1][0]
imshow(img)
print(str(answ[0][classification]*100) + '% Confidence This Is ' + names(classification))
# Out:
# 99.9903678894043% Confidence This Is meningioma_tumor

# %%
img = Image.open('testing/pituitary_tumor/image(88).jpg')
x = np.array(img.resize(dim))
x = x.reshape(1,150,150,3)
answ = model.predict_on_batch(x)
classification = np.where(answ == np.amax(answ))[1][0]
imshow(img)
print(str(answ[0][classification]*100) + '% Confidence This Is ' + names(classification))
# Out:
# 91.47163033485413% Confidence This Is pituitary_tumor
